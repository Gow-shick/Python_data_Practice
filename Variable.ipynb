# %% [markdown]
# Variable ---Storing values into some place

# %% [markdown]
# Variable declaration

# %%
a=10
b=5

# %% [markdown]
# We can use the variable where ever we need. declare one time use it many time

# %%
print('The Value of a is',a)
print('The Value of b is',b)
# Out:
# The Value of a is 10
# The Value of b is 5

# %%
print('The addition of a+b is',a+b)
# Out:
# The addition of a+b is 15

# %% [markdown]
# Multiple Varibale declaration in Single Line

# %%
c,d='ram',20
###Printing multiple varibale in single line
print('The address of',c,'is plot no',d)
# Out:
# The address of ram is plot no 20

# %% [markdown]
# We need to mention  same number of variable and values are same otherwise it will fail

# %%
a,b='rajesh','kumar',5
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 a,b='rajesh','kumar',5
#
# ValueError: too many values to unpack (expected 2)
