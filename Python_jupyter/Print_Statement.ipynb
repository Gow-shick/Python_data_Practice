# %% [markdown]
# Single Line print statement

# %%
print('Welcome to Data world')
print("Welcome to Data World")
print('''Welcome to data world''')
print("""Welcome to Data World""")
# Out:
# Welcome to Data world
# Welcome to Data World
# Welcome to data world
# Welcome to Data World

# %% [markdown]
# Multiline Print Statement --- Should use Triple Quotes

# %%
print("""
hi Welcome to data engineering world.
this is world of data """)

print('''
hi Welcome to data engineering world.
this is world of data ''')
# Out:
# hi Welcome to data engineering world.
# this is world of data
#
# hi Welcome to data engineering world.
# this is world of data
